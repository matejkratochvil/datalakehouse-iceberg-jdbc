# %%
# !pwd
# Out:
# /home/jovyan/notebooks

# %%
# !for ((i=0;i<1800000;i+=100000)); do wget "https://api.energidataservice.dk/dataset/Elspotprices?offset=$i&limit=100000&sort=HourUTC%20DESC" -O testdata/Elspotprices_$((i/100000)).json & done; wait
# Out:
# --2025-07-08 14:05:34--  https://api.energidataservice.dk/dataset/Elspotprices?offset=1700000&limit=100000&sort=HourUTC%20DESC
# --2025-07-08 14:05:34--  https://api.energidataservice.dk/dataset/Elspotprices?offset=400000&limit=100000&sort=HourUTC%20DESC
# --2025-07-08 14:05:34--  https://api.energidataservice.dk/dataset/Elspotprices?offset=900000&limit=100000&sort=HourUTC%20DESC
# --2025-07-08 14:05:34--  https://api.energidataservice.dk/dataset/Elspotprices?offset=1400000&limit=100000&sort=HourUTC%20DESC
# --2025-07-08 14:05:34--  https://api.energidataservice.dk/dataset/Elspotprices?offset=800000&limit=100000&sort=HourUTC%20DESC
# --2025-07-08 14:05:34--  https://api.energidataservice.dk/dataset/Elspotprices?offset=1000000&limit=100000&sort=HourUTC%20DESC
# --2025-07-08 14:05:34--  https://api.energidataservice.dk/dataset/Elspotprices?offset=700000&limit=100000&sort=HourUTC%20DESC
# ...

# %%
# !ls testdata
# Out:
# Elspotprices_0.json   Elspotprices_14.json  Elspotprices_4.json
# Elspotprices_1.json   Elspotprices_15.json  Elspotprices_5.json
# Elspotprices_10.json  Elspotprices_16.json  Elspotprices_6.json
# Elspotprices_11.json  Elspotprices_17.json  Elspotprices_7.json
# Elspotprices_12.json  Elspotprices_2.json   Elspotprices_8.json
# Elspotprices_13.json  Elspotprices_3.json   Elspotprices_9.json
